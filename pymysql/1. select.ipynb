# %% [markdown]
# # SELECT
# 다양한 조건을 사용하여 SELECT문을 사용해본다

# %%
import pymysql
import pandas as pd
import numpy as np
from config import *
import uuid
import datetime 
from itertools import product

# %%
def query(sql, data):
    """
    DB에 SQL문 실행(query: 데이터베이스에 정보 요청)
       Args:
           sql(str): sql 구문
           data(list or tuple): sql 파라미터. ex) [val1, val2 ...]
       Returns:
           query 결과. 결과가 없으면 빈 tuple 리턴
    """
    # connect(): DB와 연결
    db = pymysql.Connect(host=MYSQL_HOST, 
                     user=MYSQL_USER, 
                     password=MYSQL_PASSWORD, 
                     database=MYSQL_DATABASE,
                     autocommit=MYSQL_AUTOCOMMIT, # Query 실행 후 자동 commit(실제 insert, update 반영)
                     charset=MYSQL_CHARSET, # 인코딩 정보
                     cursorclass=pymysql.cursors.DictCursor # DB를 조회한 결과를 Column 명이 Key인 Dictionary로 저장
                    )
    cursor = db.cursor()

    cursor.execute(sql, data) 
    result = cursor.fetchall() # fetchall(): 모든 데이터를 한 번에 가져옴
    db.close()
    return to_pandas(result)

def to_pandas(result):
    return pd.DataFrame(result)

# %% [markdown]
# ## 기본 SELECT

# %%
# 테이블의 전체 데이터를 select
sql = "SELECT * FROM " + MYSQL_TABLENAME+ ";"
print(sql)
result = query(sql, ())
result.head()
# Out:
# SELECT * FROM mytable;
#    index                              uuid            reg_date  name  \
# 0      1  73e01babaaf511ed847040b076a1ec6b 2023-02-12 16:51:10  Choi
# 1      2  73dff493aaf511ed9dc140b076a1ec6b 2023-02-12 16:51:10   Lee
# 2      3  73dfa65faaf511ed9fb340b076a1ec6b 2023-02-12 16:51:10   Kim
# 3      4  73e01bacaaf511edb1d840b076a1ec6b 2023-02-12 15:51:10  Choi
# 4      5  73dff494aaf511ed8c0f40b076a1ec6b 2023-02-12 15:51:10   Lee
#
#             email          phone  energy  \
# 0  Choi@mysql.com  010-9876-5432      35
# 1   Lee@mysql.com  010-4567-8910      80
# 2   Kim@mysql.com  010-1234-5678      44
# 3  Choi@mysql.com  010-9876-5432      29
# 4   Lee@mysql.com  010-4567-8910       0
#
#                                            label mark ext01
# 0    [{'serach': 'naver'}, {'viewing time': 30}]
# 1  [{'serach': 'youtube'}, {'viewing time': 54}]
# 2   [{'serach': 'github'}, {'viewing time': 64}]
# 3   [{'serach': 'github'}, {'viewing time': 33}]
# 4    [{'serach': 'naver'}, {'viewing time': 19}]

# %%
result.info() # 총 144rows
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index     144 non-null    int64
#  1   uuid      144 non-null    object
#  2   reg_date  144 non-null    datetime64[ns]
#  3   name      144 non-null    object
#  4   email     144 non-null    object
#  5   phone     144 non-null    object
#  6   energy    144 non-null    int64
#  7   label     144 non-null    object
#  8   mark      144 non-null    object
#  9   ext01     144 non-null    object
# dtypes: datetime64[ns](1), int64(2), object(7)
# memory usage: 11.4+ KB

# %% [markdown]
# ## SELECT + 자주쓰는 기본 문법
# - DATE, COALESCE

# %%
sql = "SELECT DATE('2023-02-24 11:00:00');" # date 생성해서 테이블처럼 만듦
print(sql)
result = query(sql, ())
result.head()
# Out:
# SELECT DATE('2023-02-24 11:00:00');
#   DATE('2023-02-24 11:00:00')
# 0                  2023-02-24

# %%
sql = "SELECT COALESCE('2023-02-24 11:00:00', 0);" # date 생성해서 테이블처럼 만듦
print(sql)
result = query(sql, ())
result.head()
# Out:
# SELECT COALESCE('2023-02-24 11:00:00', 0);
#   COALESCE('2023-02-24 11:00:00', 0)
# 0                2023-02-24 11:00:00

# %%
sql = "SELECT COALESCE(null, 10, 5);" # 값이 null이 아니면서 가장 먼저 입력한 10이 나옴. null만 있다면 null만 나옴
print(sql)
result = query(sql, ())
result.head()
# Out:
# SELECT COALESCE(null, 10, 5);
#    COALESCE(null, 10, 5)
# 0                     10

# %% [markdown]
# ## SELECT + WHERE + 조건

# %%
# name 지정
sql = "SELECT * FROM " + MYSQL_TABLENAME +" where name=%s;" 
print(sql)
result = query(sql, (['Kim']))
result[['name']].value_counts()
# Out:
# SELECT * FROM mytable where name=%s;
# name
# Kim     48
# dtype: int64

# %%
# 시간 지정
sql = "SELECT * FROM " + MYSQL_TABLENAME +" where reg_date BETWEEN TIMESTAMP(%s) AND TIMESTAMP(%s);" 
print(sql)
result = query(sql, (['2023-02-12 00:00:00', '2023-02-13 00:00:00']))
result.sort_values('reg_date')
# Out:
# SELECT * FROM mytable where reg_date BETWEEN TIMESTAMP(%s) AND TIMESTAMP(%s);
#     index                              uuid            reg_date  name  \
# 50     51  73dfcd7caaf511eda45b40b076a1ec6b 2023-02-12 00:51:10   Kim
# 49     50  73dff4a3aaf511eda61c40b076a1ec6b 2023-02-12 00:51:10   Lee
# 48     49  73e042aaaaf511edbb8d40b076a1ec6b 2023-02-12 00:51:10  Choi
# 47     48  73dfcd7baaf511ed920b40b076a1ec6b 2023-02-12 01:51:10   Kim
# 46     47  73dff4a2aaf511eda53a40b076a1ec6b 2023-02-12 01:51:10   Lee
# 45     46  73e042a9aaf511eda98940b076a1ec6b 2023-02-12 01:51:10  Choi
# 44     45  73dfcd7aaaf511ed97bc40b076a1ec6b 2023-02-12 02:51:10   Kim
# 43     44  73dff4a1aaf511edb39540b076a1ec6b 2023-02-12 02:51:10   Lee
# 42     43  73e01bb9aaf511edb72e40b076a1ec6b 2023-02-12 02:51:10  Choi
# 41     42  73dfcd79aaf511edbb1c40b076a1ec6b 2023-02-12 03:51:10   Kim
# 40     41  73dff4a0aaf511edb24f40b076a1ec6b 2023-02-12 03:51:10   Lee
# 39     40  73e01bb8aaf511edb0bf40b076a1ec6b 2023-02-12 03:51:10  Choi
# 36     37  73e01bb7aaf511eda6ea40b076a1ec6b 2023-02-12 04:51:10  Choi
# 38     39  73dfcd78aaf511ed81bc40b076a1ec6b 2023-02-12 04:51:10   Kim
# 37     38  73dff49faaf511ed929740b076a1ec6b 2023-02-12 04:51:10   Lee
# 35     36  73dfcd77aaf511edbc0440b076a1ec6b 2023-02-12 05:51:10   Kim
# 34     35  73dff49eaaf511ed943040b076a1ec6b 2023-02-12 05:51:10   Lee
# 33     34  73e01bb6aaf511eda3e340b076a1ec6b 2023-02-12 05:51:10  Choi
# 32     33  73dfcd76aaf511ed978640b076a1ec6b 2023-02-12 06:51:10   Kim
# 31     32  73dff49daaf511eda75c40b076a1ec6b 2023-02-12 06:51:10   Lee
# 30     31  73e01bb5aaf511edb5ee40b076a1ec6b 2023-02-12 06:51:10  Choi
# 29     30  73dfcd75aaf511edae5b40b076a1ec6b 2023-02-12 07:51:10   Kim
# 28     29  73dff49caaf511ed848540b076a1ec6b 2023-02-12 07:51:10   Lee
# 27     28  73e01bb4aaf511ed96a840b076a1ec6b 2023-02-12 07:51:10  Choi
# 26     27  73dfcd74aaf511ed8b2640b076a1ec6b 2023-02-12 08:51:10   Kim
# 25     26  73dff49baaf511ed805640b076a1ec6b 2023-02-12 08:51:10   Lee
# 24     25  73e01bb3aaf511edb12840b076a1ec6b 2023-02-12 08:51:10  Choi
# 23     24  73dfcd73aaf511edbf5440b076a1ec6b 2023-02-12 09:51:10   Kim
# 22     23  73dff49aaaf511eda03d40b076a1ec6b 2023-02-12 09:51:10   Lee
# 21     22  73e01bb2aaf511eda57f40b076a1ec6b 2023-02-12 09:51:10  Choi
# 20     21  73dfcd72aaf511ed93dc40b076a1ec6b 2023-02-12 10:51:10   Kim
# 19     20  73dff499aaf511ed83ce40b076a1ec6b 2023-02-12 10:51:10   Lee
# 18     19  73e01bb1aaf511ed8ed840b076a1ec6b 2023-02-12 10:51:10  Choi
# 17     18  73dfcd71aaf511ed920240b076a1ec6b 2023-02-12 11:51:10   Kim
# 16     17  73dff498aaf511ed9bf540b076a1ec6b 2023-02-12 11:51:10   Lee
# 15     16  73e01bb0aaf511ed8e3240b076a1ec6b 2023-02-12 11:51:10  Choi
# 14     15  73dfa663aaf511edaa5940b076a1ec6b 2023-02-12 12:51:10   Kim
# 13     14  73dff497aaf511edaf8e40b076a1ec6b 2023-02-12 12:51:10   Lee
# 12     13  73e01bafaaf511ed906040b076a1ec6b 2023-02-12 12:51:10  Choi
# 9      10  73e01baeaaf511edb11540b076a1ec6b 2023-02-12 13:51:10  Choi
# 11     12  73dfa662aaf511eda43140b076a1ec6b 2023-02-12 13:51:10   Kim
# 10     11  73dff496aaf511ed837340b076a1ec6b 2023-02-12 13:51:10   Lee
# 8       9  73dfa661aaf511edb22f40b076a1ec6b 2023-02-12 14:51:10   Kim
# 7       8  73dff495aaf511eda24140b076a1ec6b 2023-02-12 14:51:10   Lee
# 6       7  73e01badaaf511edb02f40b076a1ec6b 2023-02-12 14:51:10  Choi
# 5       6  73dfa660aaf511edaebc40b076a1ec6b 2023-02-12 15:51:10   Kim
# 4       5  73dff494aaf511ed8c0f40b076a1ec6b 2023-02-12 15:51:10   Lee
# 3       4  73e01bacaaf511edb1d840b076a1ec6b 2023-02-12 15:51:10  Choi
# 2       3  73dfa65faaf511ed9fb340b076a1ec6b 2023-02-12 16:51:10   Kim
# 1       2  73dff493aaf511ed9dc140b076a1ec6b 2023-02-12 16:51:10   Lee
# 0       1  73e01babaaf511ed847040b076a1ec6b 2023-02-12 16:51:10  Choi
#
#              email          phone  energy  \
# 50   Kim@mysql.com  010-1234-5678      35
# 49   Lee@mysql.com  010-4567-8910      83
# 48  Choi@mysql.com  010-9876-5432      16
# 47   Kim@mysql.com  010-1234-5678      74
# 46   Lee@mysql.com  010-4567-8910      80
# 45  Choi@mysql.com  010-9876-5432       0
# 44   Kim@mysql.com  010-1234-5678      57
# 43   Lee@mysql.com  010-4567-8910      29
# 42  Choi@mysql.com  010-9876-5432      81
# 41   Kim@mysql.com  010-1234-5678      32
# 40   Lee@mysql.com  010-4567-8910      56
# 39  Choi@mysql.com  010-9876-5432      91
# 36  Choi@mysql.com  010-9876-5432      73
# 38   Kim@mysql.com  010-1234-5678      29
# 37   Lee@mysql.com  010-4567-8910      86
# 35   Kim@mysql.com  010-1234-5678      99
# 34   Lee@mysql.com  010-4567-8910      67
# 33  Choi@mysql.com  010-9876-5432      93
# 32   Kim@mysql.com  010-1234-5678      79
# 31   Lee@mysql.com  010-4567-8910      14
# 30  Choi@mysql.com  010-9876-5432      83
# 29   Kim@mysql.com  010-1234-5678      20
# 28   Lee@mysql.com  010-4567-8910      67
# 27  Choi@mysql.com  010-9876-5432      18
# 26   Kim@mysql.com  010-1234-5678      77
# 25   Lee@mysql.com  010-4567-8910      66
# 24  Choi@mysql.com  010-9876-5432      17
# 23   Kim@mysql.com  010-1234-5678      81
# 22   Lee@mysql.com  010-4567-8910      72
# 21  Choi@mysql.com  010-9876-5432      39
# 20   Kim@mysql.com  010-1234-5678      87
# 19   Lee@mysql.com  010-4567-8910      13
# 18  Choi@mysql.com  010-9876-5432      91
# 17   Kim@mysql.com  010-1234-5678      65
# 16   Lee@mysql.com  010-4567-8910       3
# 15  Choi@mysql.com  010-9876-5432      44
# 14   Kim@mysql.com  010-1234-5678      88
# 13   Lee@mysql.com  010-4567-8910      30
# 12  Choi@mysql.com  010-9876-5432      69
# 9   Choi@mysql.com  010-9876-5432      84
# 11   Kim@mysql.com  010-1234-5678      87
# 10   Lee@mysql.com  010-4567-8910      60
# 8    Kim@mysql.com  010-1234-5678      21
# 7    Lee@mysql.com  010-4567-8910      46
# 6   Choi@mysql.com  010-9876-5432      18
# 5    Kim@mysql.com  010-1234-5678      67
# 4    Lee@mysql.com  010-4567-8910       0
# 3   Choi@mysql.com  010-9876-5432      29
# 2    Kim@mysql.com  010-1234-5678      44
# 1    Lee@mysql.com  010-4567-8910      80
# 0   Choi@mysql.com  010-9876-5432      35
#
#                                             label mark ext01
# 50    [{'serach': 'naver'}, {'viewing time': 75}]
# 49   [{'serach': 'github'}, {'viewing time': 32}]
# 48    [{'serach': 'naver'}, {'viewing time': 36}]
# 47  [{'serach': 'youtube'}, {'viewing time': 23}]
# 46  [{'serach': 'youtube'}, {'viewing time': 61}]
# 45    [{'serach': 'naver'}, {'viewing time': 63}]
# 44  [{'serach': 'youtube'}, {'viewing time': 31}]
# 43   [{'serach': 'github'}, {'viewing time': 25}]
# 42   [{'serach': 'github'}, {'viewing time': 58}]
# 41    [{'serach': 'github'}, {'viewing time': 9}]
# 40  [{'serach': 'youtube'}, {'viewing time': 24}]
# 39   [{'serach': 'github'}, {'viewing time': 28}]
# 36   [{'serach': 'github'}, {'viewing time': 96}]
# 38    [{'serach': 'naver'}, {'viewing time': 39}]
# 37   [{'serach': 'github'}, {'viewing time': 75}]
# 35  [{'serach': 'youtube'}, {'viewing time': 49}]
# 34   [{'serach': 'github'}, {'viewing time': 11}]
# 33    [{'serach': 'naver'}, {'viewing time': 21}]
# 32  [{'serach': 'youtube'}, {'viewing time': 82}]
# 31   [{'serach': 'youtube'}, {'viewing time': 4}]
# 30   [{'serach': 'github'}, {'viewing time': 41}]
# 29  [{'serach': 'youtube'}, {'viewing time': 69}]
# 28  [{'serach': 'youtube'}, {'viewing time': 61}]
# 27  [{'serach': 'youtube'}, {'viewing time': 43}]
# 26   [{'serach': 'youtube'}, {'viewing time': 9}]
# 25  [{'serach': 'youtube'}, {'viewing time': 52}]
# 24    [{'serach': 'naver'}, {'viewing time': 71}]
# 23   [{'serach': 'github'}, {'viewing time': 25}]
# 22  [{'serach': 'youtube'}, {'viewing time': 26}]
# 21    [{'serach': 'naver'}, {'viewing time': 30}]
# 20    [{'serach': 'naver'}, {'viewing time': 88}]
# 19  [{'serach': 'youtube'}, {'viewing time': 40}]
# 18   [{'serach': 'github'}, {'viewing time': 39}]
# 17    [{'serach': 'naver'}, {'viewing time': 39}]
# 16    [{'serach': 'naver'}, {'viewing time': 98}]
# 15   [{'serach': 'github'}, {'viewing time': 66}]
# 14  [{'serach': 'youtube'}, {'viewing time': 58}]
# 13   [{'serach': 'youtube'}, {'viewing time': 2}]
# 12   [{'serach': 'github'}, {'viewing time': 12}]
# 9     [{'serach': 'github'}, {'viewing time': 2}]
# 11    [{'serach': 'naver'}, {'viewing time': 88}]
# 10  [{'serach': 'youtube'}, {'viewing time': 77}]
# 8     [{'serach': 'naver'}, {'viewing time': 36}]
# 7     [{'serach': 'naver'}, {'viewing time': 56}]
# 6    [{'serach': 'github'}, {'viewing time': 93}]
# 5    [{'serach': 'github'}, {'viewing time': 83}]
# 4     [{'serach': 'naver'}, {'viewing time': 19}]
# 3    [{'serach': 'github'}, {'viewing time': 33}]
# 2    [{'serach': 'github'}, {'viewing time': 64}]
# 1   [{'serach': 'youtube'}, {'viewing time': 54}]
# 0     [{'serach': 'naver'}, {'viewing time': 30}]

# %%
# name 지정 + 시간 지정
sql = "SELECT * FROM " + MYSQL_TABLENAME +" where name=%s AND reg_date BETWEEN TIMESTAMP(%s) AND TIMESTAMP(%s);" 
print(sql)
result = query(sql, (['Kim', '2023-02-12 00:00:00', '2023-02-13 00:00:00']))
result.sort_values('reg_date')
# Out:
# SELECT * FROM mytable where name=%s AND reg_date BETWEEN TIMESTAMP(%s) AND TIMESTAMP(%s);
#     index                              uuid            reg_date name  \
# 16     51  73dfcd7caaf511eda45b40b076a1ec6b 2023-02-12 00:51:10  Kim
# 15     48  73dfcd7baaf511ed920b40b076a1ec6b 2023-02-12 01:51:10  Kim
# 14     45  73dfcd7aaaf511ed97bc40b076a1ec6b 2023-02-12 02:51:10  Kim
# 13     42  73dfcd79aaf511edbb1c40b076a1ec6b 2023-02-12 03:51:10  Kim
# 12     39  73dfcd78aaf511ed81bc40b076a1ec6b 2023-02-12 04:51:10  Kim
# 11     36  73dfcd77aaf511edbc0440b076a1ec6b 2023-02-12 05:51:10  Kim
# 10     33  73dfcd76aaf511ed978640b076a1ec6b 2023-02-12 06:51:10  Kim
# 9      30  73dfcd75aaf511edae5b40b076a1ec6b 2023-02-12 07:51:10  Kim
# 8      27  73dfcd74aaf511ed8b2640b076a1ec6b 2023-02-12 08:51:10  Kim
# 7      24  73dfcd73aaf511edbf5440b076a1ec6b 2023-02-12 09:51:10  Kim
# 6      21  73dfcd72aaf511ed93dc40b076a1ec6b 2023-02-12 10:51:10  Kim
# 5      18  73dfcd71aaf511ed920240b076a1ec6b 2023-02-12 11:51:10  Kim
# 4      15  73dfa663aaf511edaa5940b076a1ec6b 2023-02-12 12:51:10  Kim
# 3      12  73dfa662aaf511eda43140b076a1ec6b 2023-02-12 13:51:10  Kim
# 2       9  73dfa661aaf511edb22f40b076a1ec6b 2023-02-12 14:51:10  Kim
# 1       6  73dfa660aaf511edaebc40b076a1ec6b 2023-02-12 15:51:10  Kim
# 0       3  73dfa65faaf511ed9fb340b076a1ec6b 2023-02-12 16:51:10  Kim
#
#             email          phone  energy  \
# 16  Kim@mysql.com  010-1234-5678      35
# 15  Kim@mysql.com  010-1234-5678      74
# 14  Kim@mysql.com  010-1234-5678      57
# 13  Kim@mysql.com  010-1234-5678      32
# 12  Kim@mysql.com  010-1234-5678      29
# 11  Kim@mysql.com  010-1234-5678      99
# 10  Kim@mysql.com  010-1234-5678      79
# 9   Kim@mysql.com  010-1234-5678      20
# 8   Kim@mysql.com  010-1234-5678      77
# 7   Kim@mysql.com  010-1234-5678      81
# 6   Kim@mysql.com  010-1234-5678      87
# 5   Kim@mysql.com  010-1234-5678      65
# 4   Kim@mysql.com  010-1234-5678      88
# 3   Kim@mysql.com  010-1234-5678      87
# 2   Kim@mysql.com  010-1234-5678      21
# 1   Kim@mysql.com  010-1234-5678      67
# 0   Kim@mysql.com  010-1234-5678      44
#
#                                             label mark ext01
# 16    [{'serach': 'naver'}, {'viewing time': 75}]
# 15  [{'serach': 'youtube'}, {'viewing time': 23}]
# 14  [{'serach': 'youtube'}, {'viewing time': 31}]
# 13    [{'serach': 'github'}, {'viewing time': 9}]
# 12    [{'serach': 'naver'}, {'viewing time': 39}]
# 11  [{'serach': 'youtube'}, {'viewing time': 49}]
# 10  [{'serach': 'youtube'}, {'viewing time': 82}]
# 9   [{'serach': 'youtube'}, {'viewing time': 69}]
# 8    [{'serach': 'youtube'}, {'viewing time': 9}]
# 7    [{'serach': 'github'}, {'viewing time': 25}]
# 6     [{'serach': 'naver'}, {'viewing time': 88}]
# 5     [{'serach': 'naver'}, {'viewing time': 39}]
# 4   [{'serach': 'youtube'}, {'viewing time': 58}]
# 3     [{'serach': 'naver'}, {'viewing time': 88}]
# 2     [{'serach': 'naver'}, {'viewing time': 36}]
# 1    [{'serach': 'github'}, {'viewing time': 83}]
# 0    [{'serach': 'github'}, {'viewing time': 64}]

# %% [markdown]
# ## SELECT + LIMIT
# - 조회 개수 제한
# - 참고로 String Format을 사용하면 d %s %f 등 지정해주는 것이 맞지만 pymysql에서 변수 타입과 상관없이 전부 %s를 사용해줘야 한다

# %%
# name 지정
sql = "SELECT * FROM " + MYSQL_TABLENAME +" where name=%s LIMIT %s;" # 변수 타입 상관없이 %s
print(sql)
result = query(sql, (['Kim', 5])) 
result[['name']].value_counts()
# Out:
# SELECT * FROM mytable where name=%s LIMIT %s;
# name
# Kim     5
# dtype: int64

# %%
result
# Out:
#    index                              uuid            reg_date name  \
# 0      3  73dfa65faaf511ed9fb340b076a1ec6b 2023-02-12 16:51:10  Kim
# 1      6  73dfa660aaf511edaebc40b076a1ec6b 2023-02-12 15:51:10  Kim
# 2      9  73dfa661aaf511edb22f40b076a1ec6b 2023-02-12 14:51:10  Kim
# 3     12  73dfa662aaf511eda43140b076a1ec6b 2023-02-12 13:51:10  Kim
# 4     15  73dfa663aaf511edaa5940b076a1ec6b 2023-02-12 12:51:10  Kim
#
#            email          phone  energy  \
# 0  Kim@mysql.com  010-1234-5678      44
# 1  Kim@mysql.com  010-1234-5678      67
# 2  Kim@mysql.com  010-1234-5678      21
# 3  Kim@mysql.com  010-1234-5678      87
# 4  Kim@mysql.com  010-1234-5678      88
#
#                                            label mark ext01
# 0   [{'serach': 'github'}, {'viewing time': 64}]
# 1   [{'serach': 'github'}, {'viewing time': 83}]
# 2    [{'serach': 'naver'}, {'viewing time': 36}]
# 3    [{'serach': 'naver'}, {'viewing time': 88}]
# 4  [{'serach': 'youtube'}, {'viewing time': 58}]

# %% [markdown]
# ## SELECT + ORDER BY + LIMIT N,M
# - 오름차순으로 내림/오름 차순으로 정렬 뒤에 N행 부터 M개 행을 가져옴
#     - LIMITE N, M: N행에서부터 M개를 가져옴

# %%
# LIMIT로 지정한 행을 가져올 수 있음 
sql = "SELECT * FROM " + MYSQL_TABLENAME +" where name=%s ORDER BY reg_date DESC  LIMIT %s, %s;" # 내림차순
print(sql)
result = query(sql, (['Kim', 2, 5])) 
result
# Out:
# SELECT * FROM mytable where name=%s ORDER BY reg_date DESC  LIMIT %s, %s;
#    index                              uuid            reg_date name  \
# 0      9  73dfa661aaf511edb22f40b076a1ec6b 2023-02-12 14:51:10  Kim
# 1     12  73dfa662aaf511eda43140b076a1ec6b 2023-02-12 13:51:10  Kim
# 2     15  73dfa663aaf511edaa5940b076a1ec6b 2023-02-12 12:51:10  Kim
# 3     18  73dfcd71aaf511ed920240b076a1ec6b 2023-02-12 11:51:10  Kim
# 4     21  73dfcd72aaf511ed93dc40b076a1ec6b 2023-02-12 10:51:10  Kim
#
#            email          phone  energy  \
# 0  Kim@mysql.com  010-1234-5678      21
# 1  Kim@mysql.com  010-1234-5678      87
# 2  Kim@mysql.com  010-1234-5678      88
# 3  Kim@mysql.com  010-1234-5678      65
# 4  Kim@mysql.com  010-1234-5678      87
#
#                                            label mark ext01
# 0    [{'serach': 'naver'}, {'viewing time': 36}]
# 1    [{'serach': 'naver'}, {'viewing time': 88}]
# 2  [{'serach': 'youtube'}, {'viewing time': 58}]
# 3    [{'serach': 'naver'}, {'viewing time': 39}]
# 4    [{'serach': 'naver'}, {'viewing time': 88}]

# %% [markdown]
# ## SELECT + COUNT

# %%
# row counts
sql = "SELECT COUNT(*) FROM " + MYSQL_TABLENAME +";" # 내림차순
print(sql)
result = query(sql, ()) 
result
# Out:
# SELECT COUNT(*) FROM mytable;
#    COUNT(*)
# 0       144

# %%
# row counts + 조건문
sql = "SELECT COUNT(*) FROM " + MYSQL_TABLENAME +" where name=%s;" # 내림차순
print(sql)
result = query(sql, (['Kim'])) 
result
# Out:
# SELECT COUNT(*) FROM mytable where name=%s;
#    COUNT(*)
# 0        48

# %% [markdown]
# ## SELECT + LIKE
# - 특정 문자열이 있는지 검색 LIKE에 붙는 '%'위치에 따라 조건이 다름

# %%
# "[{'serach':%": [{'serach':로 시작하는 데이터 검색
sql = "SELECT * FROM " + MYSQL_TABLENAME + " where label LIKE %s;"
print(sql)
result = query(sql, ([ "[{'serach':%" ])) 
result
# Out:
# SELECT * FROM mytable where label LIKE %s;
#      index                              uuid            reg_date  name  \
# 0        1  73e01babaaf511ed847040b076a1ec6b 2023-02-12 16:51:10  Choi
# 1        2  73dff493aaf511ed9dc140b076a1ec6b 2023-02-12 16:51:10   Lee
# 2        3  73dfa65faaf511ed9fb340b076a1ec6b 2023-02-12 16:51:10   Kim
# 3        4  73e01bacaaf511edb1d840b076a1ec6b 2023-02-12 15:51:10  Choi
# 4        5  73dff494aaf511ed8c0f40b076a1ec6b 2023-02-12 15:51:10   Lee
# ..     ...                               ...                 ...   ...
# 139    140  73e01ba9aaf511ed9a4440b076a1ec6b 2023-02-10 18:51:10   Lee
# 140    141  73dff491aaf511ed8e4040b076a1ec6b 2023-02-10 18:51:10   Kim
# 141    142  73e042c9aaf511eda63640b076a1ec6b 2023-02-10 17:51:10  Choi
# 142    143  73e01baaaaf511ed97b340b076a1ec6b 2023-02-10 17:51:10   Lee
# 143    144  73dff492aaf511edb23340b076a1ec6b 2023-02-10 17:51:10   Kim
#
#               email          phone  energy  \
# 0    Choi@mysql.com  010-9876-5432      35
# 1     Lee@mysql.com  010-4567-8910      80
# 2     Kim@mysql.com  010-1234-5678      44
# 3    Choi@mysql.com  010-9876-5432      29
# 4     Lee@mysql.com  010-4567-8910       0
# ..              ...            ...     ...
# 139   Lee@mysql.com  010-4567-8910      91
# 140   Kim@mysql.com  010-1234-5678      10
# 141  Choi@mysql.com  010-9876-5432      66
# 142   Lee@mysql.com  010-4567-8910      48
# 143   Kim@mysql.com  010-1234-5678      11
#
#                                              label mark ext01
# 0      [{'serach': 'naver'}, {'viewing time': 30}]
# 1    [{'serach': 'youtube'}, {'viewing time': 54}]
# 2     [{'serach': 'github'}, {'viewing time': 64}]
# 3     [{'serach': 'github'}, {'viewing time': 33}]
# 4      [{'serach': 'naver'}, {'viewing time': 19}]
# ..                                             ...  ...   ...
# 139  [{'serach': 'youtube'}, {'viewing time': 36}]
# 140    [{'serach': 'naver'}, {'viewing time': 43}]
# 141  [{'serach': 'youtube'}, {'viewing time': 16}]
# 142   [{'serach': 'github'}, {'viewing time': 67}]
# 143    [{'serach': 'naver'}, {'viewing time': 51}]
#
# [144 rows x 10 columns]

# %%
# "%64}]": 64}]로 끝나는 데이터 검색
sql = "SELECT * FROM " + MYSQL_TABLENAME + " where label LIKE %s;"
print(sql)
result = query(sql, ([ "%64}]" ])) 
result
# Out:
# SELECT * FROM mytable where label LIKE %s;
#    index                              uuid            reg_date name  \
# 0      3  73dfa65faaf511ed9fb340b076a1ec6b 2023-02-12 16:51:10  Kim
#
#            email          phone  energy  \
# 0  Kim@mysql.com  010-1234-5678      44
#
#                                           label mark ext01
# 0  [{'serach': 'github'}, {'viewing time': 64}]

# %%
# "%[{'serach': 'youtube'}%": [{'serach': 'youtube'}이 포함되는 데이터 검색
sql = "SELECT * FROM " + MYSQL_TABLENAME + " where label LIKE %s;"
print(sql)
result = query(sql, ([ "%[{'serach': 'youtube'}%" ])) 
result
# Out:
# SELECT * FROM mytable where label LIKE %s;
#     index                              uuid            reg_date  name  \
# 0       2  73dff493aaf511ed9dc140b076a1ec6b 2023-02-12 16:51:10   Lee
# 1      11  73dff496aaf511ed837340b076a1ec6b 2023-02-12 13:51:10   Lee
# 2      14  73dff497aaf511edaf8e40b076a1ec6b 2023-02-12 12:51:10   Lee
# 3      15  73dfa663aaf511edaa5940b076a1ec6b 2023-02-12 12:51:10   Kim
# 4      20  73dff499aaf511ed83ce40b076a1ec6b 2023-02-12 10:51:10   Lee
# 5      23  73dff49aaaf511eda03d40b076a1ec6b 2023-02-12 09:51:10   Lee
# 6      26  73dff49baaf511ed805640b076a1ec6b 2023-02-12 08:51:10   Lee
# 7      27  73dfcd74aaf511ed8b2640b076a1ec6b 2023-02-12 08:51:10   Kim
# 8      28  73e01bb4aaf511ed96a840b076a1ec6b 2023-02-12 07:51:10  Choi
# 9      29  73dff49caaf511ed848540b076a1ec6b 2023-02-12 07:51:10   Lee
# 10     30  73dfcd75aaf511edae5b40b076a1ec6b 2023-02-12 07:51:10   Kim
# 11     32  73dff49daaf511eda75c40b076a1ec6b 2023-02-12 06:51:10   Lee
# 12     33  73dfcd76aaf511ed978640b076a1ec6b 2023-02-12 06:51:10   Kim
# 13     36  73dfcd77aaf511edbc0440b076a1ec6b 2023-02-12 05:51:10   Kim
# 14     41  73dff4a0aaf511edb24f40b076a1ec6b 2023-02-12 03:51:10   Lee
# 15     45  73dfcd7aaaf511ed97bc40b076a1ec6b 2023-02-12 02:51:10   Kim
# 16     47  73dff4a2aaf511eda53a40b076a1ec6b 2023-02-12 01:51:10   Lee
# 17     48  73dfcd7baaf511ed920b40b076a1ec6b 2023-02-12 01:51:10   Kim
# 18     52  73e042abaaf511ed82c440b076a1ec6b 2023-02-11 23:51:10  Choi
# 19     54  73dfcd7daaf511ed860540b076a1ec6b 2023-02-11 23:51:10   Kim
# 20     55  73e042acaaf511edba5d40b076a1ec6b 2023-02-11 22:51:10  Choi
# 21     56  73dff4a5aaf511ed823f40b076a1ec6b 2023-02-11 22:51:10   Lee
# 22     57  73dfcd7eaaf511edb03540b076a1ec6b 2023-02-11 22:51:10   Kim
# 23     61  73e042aeaaf511edb88340b076a1ec6b 2023-02-11 20:51:10  Choi
# 24     63  73dfcd80aaf511ed8e7b40b076a1ec6b 2023-02-11 20:51:10   Kim
# 25     66  73dfcd81aaf511edbefe40b076a1ec6b 2023-02-11 19:51:10   Kim
# 26     67  73e042b0aaf511eda94140b076a1ec6b 2023-02-11 18:51:10  Choi
# 27     70  73e042b1aaf511edb09a40b076a1ec6b 2023-02-11 17:51:10  Choi
# 28     73  73e042b2aaf511ed9bad40b076a1ec6b 2023-02-11 16:51:10  Choi
# 29     81  73dfcd86aaf511ed920440b076a1ec6b 2023-02-11 14:51:10   Kim
# 30     83  73e01b96aaf511edb5b840b076a1ec6b 2023-02-11 13:51:10   Lee
# 31     84  73dfcd87aaf511ed93c240b076a1ec6b 2023-02-11 13:51:10   Kim
# 32     85  73e042b6aaf511ed80b240b076a1ec6b 2023-02-11 12:51:10  Choi
# 33     87  73dfcd88aaf511ed947240b076a1ec6b 2023-02-11 12:51:10   Kim
# 34     90  73dfcd89aaf511edbbaa40b076a1ec6b 2023-02-11 11:51:10   Kim
# 35     93  73dfcd8aaaf511ed8b9f40b076a1ec6b 2023-02-11 10:51:10   Kim
# 36     94  73e042b9aaf511edb16240b076a1ec6b 2023-02-11 09:51:10  Choi
# 37    102  73dfcd8daaf511edad5e40b076a1ec6b 2023-02-11 07:51:10   Kim
# 38    106  73e042bdaaf511ed8a6e40b076a1ec6b 2023-02-11 05:51:10  Choi
# 39    107  73e01b9eaaf511ed8a4040b076a1ec6b 2023-02-11 05:51:10   Lee
# 40    108  73dfcd8faaf511ed81d440b076a1ec6b 2023-02-11 05:51:10   Kim
# 41    112  73e042bfaaf511ed86b740b076a1ec6b 2023-02-11 03:51:10  Choi
# 42    115  73e042c0aaf511edabf640b076a1ec6b 2023-02-11 02:51:10  Choi
# 43    119  73e01ba2aaf511ed844c40b076a1ec6b 2023-02-11 01:51:10   Lee
# 44    121  73e042c2aaf511edb2d940b076a1ec6b 2023-02-11 00:51:10  Choi
# 45    122  73e01ba3aaf511edbf6f40b076a1ec6b 2023-02-11 00:51:10   Lee
# 46    125  73e01ba4aaf511edb88140b076a1ec6b 2023-02-10 23:51:10   Lee
# 47    130  73e042c5aaf511ed801e40b076a1ec6b 2023-02-10 21:51:10  Choi
# 48    134  73e01ba7aaf511ed9ad440b076a1ec6b 2023-02-10 20:51:10   Lee
# 49    139  73e042c8aaf511ed902040b076a1ec6b 2023-02-10 18:51:10  Choi
# 50    140  73e01ba9aaf511ed9a4440b076a1ec6b 2023-02-10 18:51:10   Lee
# 51    142  73e042c9aaf511eda63640b076a1ec6b 2023-02-10 17:51:10  Choi
#
#              email          phone  energy  \
# 0    Lee@mysql.com  010-4567-8910      80
# 1    Lee@mysql.com  010-4567-8910      60
# 2    Lee@mysql.com  010-4567-8910      30
# 3    Kim@mysql.com  010-1234-5678      88
# 4    Lee@mysql.com  010-4567-8910      13
# 5    Lee@mysql.com  010-4567-8910      72
# 6    Lee@mysql.com  010-4567-8910      66
# 7    Kim@mysql.com  010-1234-5678      77
# 8   Choi@mysql.com  010-9876-5432      18
# 9    Lee@mysql.com  010-4567-8910      67
# 10   Kim@mysql.com  010-1234-5678      20
# 11   Lee@mysql.com  010-4567-8910      14
# 12   Kim@mysql.com  010-1234-5678      79
# 13   Kim@mysql.com  010-1234-5678      99
# 14   Lee@mysql.com  010-4567-8910      56
# 15   Kim@mysql.com  010-1234-5678      57
# 16   Lee@mysql.com  010-4567-8910      80
# 17   Kim@mysql.com  010-1234-5678      74
# 18  Choi@mysql.com  010-9876-5432      94
# 19   Kim@mysql.com  010-1234-5678      55
# 20  Choi@mysql.com  010-9876-5432      67
# 21   Lee@mysql.com  010-4567-8910      13
# 22   Kim@mysql.com  010-1234-5678       0
# 23  Choi@mysql.com  010-9876-5432      32
# 24   Kim@mysql.com  010-1234-5678      17
# 25   Kim@mysql.com  010-1234-5678      58
# 26  Choi@mysql.com  010-9876-5432      81
# 27  Choi@mysql.com  010-9876-5432      64
# 28  Choi@mysql.com  010-9876-5432      25
# 29   Kim@mysql.com  010-1234-5678      53
# 30   Lee@mysql.com  010-4567-8910      69
# 31   Kim@mysql.com  010-1234-5678      84
# 32  Choi@mysql.com  010-9876-5432       7
# 33   Kim@mysql.com  010-1234-5678      68
# 34   Kim@mysql.com  010-1234-5678      76
# 35   Kim@mysql.com  010-1234-5678      78
# 36  Choi@mysql.com  010-9876-5432       4
# 37   Kim@mysql.com  010-1234-5678      41
# 38  Choi@mysql.com  010-9876-5432      58
# 39   Lee@mysql.com  010-4567-8910      50
# 40   Kim@mysql.com  010-1234-5678      50
# 41  Choi@mysql.com  010-9876-5432      53
# 42  Choi@mysql.com  010-9876-5432      59
# 43   Lee@mysql.com  010-4567-8910      97
# 44  Choi@mysql.com  010-9876-5432      73
# 45   Lee@mysql.com  010-4567-8910      34
# 46   Lee@mysql.com  010-4567-8910       5
# 47  Choi@mysql.com  010-9876-5432      80
# 48   Lee@mysql.com  010-4567-8910      62
# 49  Choi@mysql.com  010-9876-5432      71
# 50   Lee@mysql.com  010-4567-8910      91
# 51  Choi@mysql.com  010-9876-5432      66
#
#                                             label mark ext01
# 0   [{'serach': 'youtube'}, {'viewing time': 54}]
# 1   [{'serach': 'youtube'}, {'viewing time': 77}]
# 2    [{'serach': 'youtube'}, {'viewing time': 2}]
# 3   [{'serach': 'youtube'}, {'viewing time': 58}]
# 4   [{'serach': 'youtube'}, {'viewing time': 40}]
# 5   [{'serach': 'youtube'}, {'viewing time': 26}]
# 6   [{'serach': 'youtube'}, {'viewing time': 52}]
# 7    [{'serach': 'youtube'}, {'viewing time': 9}]
# 8   [{'serach': 'youtube'}, {'viewing time': 43}]
# 9   [{'serach': 'youtube'}, {'viewing time': 61}]
# 10  [{'serach': 'youtube'}, {'viewing time': 69}]
# 11   [{'serach': 'youtube'}, {'viewing time': 4}]
# 12  [{'serach': 'youtube'}, {'viewing time': 82}]
# 13  [{'serach': 'youtube'}, {'viewing time': 49}]
# 14  [{'serach': 'youtube'}, {'viewing time': 24}]
# 15  [{'serach': 'youtube'}, {'viewing time': 31}]
# 16  [{'serach': 'youtube'}, {'viewing time': 61}]
# 17  [{'serach': 'youtube'}, {'viewing time': 23}]
# 18  [{'serach': 'youtube'}, {'viewing time': 63}]
# 19  [{'serach': 'youtube'}, {'viewing time': 34}]
# 20  [{'serach': 'youtube'}, {'viewing time': 56}]
# 21  [{'serach': 'youtube'}, {'viewing time': 24}]
# 22  [{'serach': 'youtube'}, {'viewing time': 36}]
# 23  [{'serach': 'youtube'}, {'viewing time': 71}]
# 24  [{'serach': 'youtube'}, {'viewing time': 42}]
# 25   [{'serach': 'youtube'}, {'viewing time': 1}]
# 26  [{'serach': 'youtube'}, {'viewing time': 55}]
# 27  [{'serach': 'youtube'}, {'viewing time': 36}]
# 28  [{'serach': 'youtube'}, {'viewing time': 42}]
# 29  [{'serach': 'youtube'}, {'viewing time': 42}]
# 30  [{'serach': 'youtube'}, {'viewing time': 11}]
# 31   [{'serach': 'youtube'}, {'viewing time': 6}]
# 32  [{'serach': 'youtube'}, {'viewing time': 61}]
# 33   [{'serach': 'youtube'}, {'viewing time': 3}]
# 34  [{'serach': 'youtube'}, {'viewing time': 52}]
# 35  [{'serach': 'youtube'}, {'viewing time': 99}]
# 36  [{'serach': 'youtube'}, {'viewing time': 45}]
# 37  [{'serach': 'youtube'}, {'viewing time': 95}]
# 38  [{'serach': 'youtube'}, {'viewing time': 18}]
# 39   [{'serach': 'youtube'}, {'viewing time': 3}]
# 40  [{'serach': 'youtube'}, {'viewing time': 34}]
# 41  [{'serach': 'youtube'}, {'viewing time': 94}]
# 42  [{'serach': 'youtube'}, {'viewing time': 26}]
# 43  [{'serach': 'youtube'}, {'viewing time': 34}]
# 44  [{'serach': 'youtube'}, {'viewing time': 13}]
# 45  [{'serach': 'youtube'}, {'viewing time': 33}]
# 46  [{'serach': 'youtube'}, {'viewing time': 36}]
# 47  [{'serach': 'youtube'}, {'viewing time': 22}]
# 48  [{'serach': 'youtube'}, {'viewing time': 61}]
# 49  [{'serach': 'youtube'}, {'viewing time': 89}]
# 50  [{'serach': 'youtube'}, {'viewing time': 36}]
# 51  [{'serach': 'youtube'}, {'viewing time': 16}]
